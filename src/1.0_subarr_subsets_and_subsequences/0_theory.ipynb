# %% [markdown]
# ### Subsets
#
# To explain the subsets of the set
# ```
# [1,2,3,4]
# ```
# A subset is any collection of elements that are all drawn from the original set, including the possibility of the empty set and the set itself.
#
#
# Let's list all the subsets:
#
# The total number of subsets of a set with
# n elements is given by
# 2^n. For a set with 4 elements, the total number of subsets is:
#
# 2^4 = 16
#
# So, there are 16 subsets in total.
#
# ```
# [1,2,3,4]
# ```
#
# 1. {}
#
# Subsets with 1 element:
#
# 2. {1}
# 3. {2}
# 4. {3}
# 5. {4}
#
# Subsets with 2 elements:
#
# 6. {1,2}
# 7. {1,3}
# 8. {1,4}
# 9. {2,3}
# 10. {2,4}
# 11. {3,4}
#
# Subsets with 3 elements:
#
# 12. {1,2,3}
# 13. {1,2,4}
# 14. {1,3,4}
# 15. {2,3,4}
#
# Subset with all 4 elements:
#
# 16. {1,2,3,4}

# %% [markdown]
# ### Subsequences
#
# Subsequences are sequences derived from another sequence by deleting some or no elements **without changing the order** of the remaining elements. The number of subsequences of a sequence with n elements is given by the formula 2^n.
#
# Examples of subsequences for {1, 2, 3}:
#
# Empty subsequence:
#
# 1. {}
#
# Subsequences with 1 element:
#
# 2. {1}
# 3. {2}
# 4. {3}
#
# Subsequences with 2 elements:
#
# 5. {1,2}
# 6. {1,3}
# 7. {2,3}
#
# Subsequence with all 3 elements:
#
# 8. {1,2,3}
#
# Total number of subsequences: 8 (2^3 = 8)

# %% [markdown]
# ### Key Differences Subsets VS Subsequences
#
# Subsets vs. Subsequences:
#
# 1. **Order of Elements:**
#    - **Subsets:** Order does not matter. Elements can appear in any order.
#    - **Subsequences:** Order matters. Elements must appear in the same order as they do in the original sequence.
#
# 2. **Definition:**
#    - **Subsets:** A subset is any combination of elements from a set, including the empty set and the set itself. **[1,2] and [2,1]** are considered the **same subset.**
#    - **Subsequences:** A subsequence is a sequence derived from another sequence by deleting some or no elements without changing the order of the remaining elements.
#
# 3. **Total Number:**
#    - **Subsets:** For a set with \( n \) elements, there are \( 2^n \) subsets.
#    - **Subsequences:** For a sequence with \( n \) elements, there are \( 2^n \) subsequences.
#
# 4. **Examples:**
#
#    - **Subsets of {1, 2, 3, 4}:**
#      - Empty subset: {}
#      - Subsets with 1 element: {1}, {2}, {3}, {4}
#      - Subsets with 2 elements: {1,2}, {1,3}, {1,4}, {2,3}, {2,4}, {3,4}
#      - Subsets with 3 elements: {1,2,3}, {1,2,4}, {1,3,4}, {2,3,4}
#      - Subset with all 4 elements: {1,2,3,4}
#      - Note: {1,2} and {2,1} are considered the same subset.
#
#    - **Subsequences of {1, 2, 3, 4}:**
#      - Empty subsequence: {}
#      - Subsequences with 1 element: {1}, {2}, {3}, {4}
#      - Subsequences with 2 elements: {1,2}, {1,3}, {1,4}, {2,3}, {2,4}, {3,4}
#      - Subsequences with 3 elements: {1,2,3}, {1,2,4}, {1,3,4}, {2,3,4}
#      - Subsequence with all 4 elements: {1,2,3,4}
#      - Note: {1,3} is a subsequence, but {3,1} is not (order matters).
#
# In summary, subsets are combinations of elements without regard to order, while subsequences are ordered selections that respect the original sequence's order.

# %% [markdown]
# <img src="./img/subarr.png" alt="nearby_objects" width="500"/>
#
# <img src="./img/subseq.png" alt="nearby_objects" width="500"/>
#
# <img src="./img/subset.png" alt="nearby_objects" width="500"/>
